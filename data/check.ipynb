# %%
import pandas as pd

# %%
dat = pd.read_parquet("mock_tmt_daily.parquet")

# %%
dat.head()
# Out:
#                                      open       high        low      close  \
# Datetime            Contract
# 2023-01-03 15:00:00 TMT0001.SZ  48.000713  48.387455  47.635288  48.021870
#                     TMT0002.SH  23.073788  23.133926  22.978764  23.038811
#                     TMT0003.SZ  71.299988  71.742577  70.926010  71.368240
#                     TMT0004.SH  32.131767  32.563412  31.641838  32.072685
#                     TMT0005.SZ  38.727695  39.134937  38.349075  38.756039
#
#                                     volume       amount  turnover  market_cap  \
# Datetime            Contract
# 2023-01-03 15:00:00 TMT0001.SZ  2914399.25  139954896.0  0.008893  157.380157
#                     TMT0002.SH  7139635.00  164488704.0  0.010747  153.061707
#                     TMT0003.SZ  2335524.50  166682256.0  0.009805  170.004547
#                     TMT0004.SH  1353451.50   43408824.0  0.009968   43.550201
# ...
